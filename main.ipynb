# %%
import pandas as pd
import numpy as np
import os
import random
# !pip install optuna

from sklearn.preprocessing import LabelEncoder, MaxAbsScaler
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split, KFold
import optuna

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# Seed 설정
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42)

# %%
# 데이터 로드
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python3/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python3/test.csv')

# %%
# 이상치 처리: 중앙값으로 치환
median_pressure_train = train['pressure'].median()
median_pressure_test = test['pressure'].median()

train.loc[train['pressure'] <= 850, 'pressure'] = median_pressure_train
test.loc[test['pressure'] <= 850, 'pressure'] = median_pressure_test

train.loc[train['pressure'] >= 1100, 'pressure'] = median_pressure_train
test.loc[test['pressure'] >= 1200, 'pressure'] = median_pressure_test

# %%
# 대기 밀도 계산
def air_density(pressure, temperature, humidity):
    R = 287.05  # specific gas constant in J/(kg·K)
    T = temperature + 273.15  # Convert temperature from Celsius to Kelvin
    e = (humidity/100) * 6.105 * np.exp((17.27 * temperature) / (237.7 + temperature))  # vapour pressure
    pv = e * 100  # vapour partial pressure in Pa
    pd = pressure * 100 - pv  # dry partial pressure in Pa
    rho = (pd / (R * T)) + (pv / (R * 461.495))  # total air density in kg/m^3
    return rho

# 절대 습도 계산
def calculate_absolute_humidity(temperature, pressure, humidity):
    T = temperature + 273.15  # Convert temperature from Celsius to Kelvin
    e = (humidity/100) * 6.105 * np.exp((17.27 * temperature) / (237.7 + temperature))  # vapour pressure
    AH = 216.7 * (e / T)
    return AH

# 공기 분압 계산
def calculate_air_pressure(pressure, temperature, humidity):
    e = (humidity/100) * 6.105 * np.exp((17.27 * temperature) / (237.7 + temperature))  # vapour pressure
    pv = e * 100  # vapour partial pressure in Pa
    return pv

# 대기 밀도, 절대 습도, 공기 분압 값을 데이터 프레임에 추가
train['air_density'] = air_density(train['pressure'], train['temperature'], train['humidity'])
test['air_density'] = air_density(test['pressure'], test['temperature'], test['humidity'])

train['absolute_humidity'] = calculate_absolute_humidity(train['temperature'], train['pressure'], train['humidity'])
test['absolute_humidity'] = calculate_absolute_humidity(test['temperature'], test['pressure'], test['humidity'])

train['air_pressure'] = calculate_air_pressure(train['pressure'], train['temperature'], train['humidity'])
test['air_pressure'] = calculate_air_pressure(test['pressure'], test['temperature'], test['humidity'])


# 독립변수와 종속변수 분리
train_x = train.drop(columns=['id', 'target'])
train_y = train['target']
test_x = test.drop(columns=['id'])

# 레이블 인코딩
le = LabelEncoder()
train_x['snowing'] = le.fit_transform(train_x['snowing'])

for label in np.unique(test_x['snowing']):
    if label not in le.classes_:
        le.classes_ = np.append(le.classes_, label)
test_x['snowing'] = le.transform(test_x['snowing'])

# 스케일링
scaler = MaxAbsScaler()
transformed_train_X = scaler.fit_transform(train_x)
transformed_test_X = scaler.transform(test_x)

# %%
# Hyperparameter Optimization with Cross-validation
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, 10),
        'max_depth': trial.suggest_int('max_depth',20, 50),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 2),
        #'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 4),
        #'max_features': trial.suggest_categorical('max_features', [None]),
        'bootstrap': trial.suggest_categorical('bootstrap', [False])
    }

    model = ExtraTreesRegressor(**params, random_state=42)

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    mae_scores = []
    for train_idx, valid_idx in kf.split(transformed_train_X):
        X_train_fold, X_valid_fold = transformed_train_X[train_idx], transformed_train_X[valid_idx]
        y_train_fold, y_valid_fold = train_y.iloc[train_idx], train_y.iloc[valid_idx]

        model.fit(X_train_fold, y_train_fold)
        preds = model.predict(X_valid_fold)
        mae_scores.append(mean_absolute_error(y_valid_fold, preds))

    return np.mean(mae_scores)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=150)  # 줄어든 n_trials로 변경

# Best Model
params = study.best_params
model = ExtraTreesRegressor(**params, random_state=42)
model.fit(transformed_train_X, train['target'])
preds = model.predict(transformed_test_X)

# %%
# Submission
submit = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python3/sample_submission.csv')
submit['target'] = preds
submit.to_csv('/content/drive/MyDrive/Colab Notebooks/python3/yangjinyeong.csv', index=False)

# %%
import pandas as pd
import numpy as np
import os
import random
# !pip install optuna

from sklearn.preprocessing import LabelEncoder, MaxAbsScaler
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split, KFold
import optuna

from google.colab import drive
drive.mount('/content/drive/')

# Seed 설정
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42)

# 데이터 로드
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python3/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python3/test.csv')

# 이상치 처리: 중앙값으로 치환
median_pressure_train = train['pressure'].median()
median_pressure_test = test['pressure'].median()

train.loc[train['pressure'] <= 850, 'pressure'] = median_pressure_train
test.loc[test['pressure'] <= 850, 'pressure'] = median_pressure_test

train.loc[train['pressure'] >= 1100, 'pressure'] = median_pressure_train
test.loc[test['pressure'] >= 1200, 'pressure'] = median_pressure_test


# 대기 밀도 계산
def air_density(pressure, temperature, humidity):
    R = 287.05  # specific gas constant in J/(kg·K)
    T = temperature + 273.15  # Convert temperature from Celsius to Kelvin
    e = (humidity/100) * 6.105 * np.exp((17.27 * temperature) / (237.7 + temperature))  # vapour pressure
    pv = e * 100  # vapour partial pressure in Pa
    pd = pressure * 100 - pv  # dry partial pressure in Pa
    rho = (pd / (R * T)) + (pv / (R * 461.495))  # total air density in kg/m^3
    return rho

# 절대 습도 계산
def calculate_absolute_humidity(temperature, pressure, humidity):
    T = temperature + 273.15  # Convert temperature from Celsius to Kelvin
    e = (humidity/100) * 6.105 * np.exp((17.27 * temperature) / (237.7 + temperature))  # vapour pressure
    AH = 216.7 * (e / T)
    return AH

# 공기 분압 계산
def calculate_air_pressure(pressure, temperature, humidity):
    e = (humidity/100) * 6.105 * np.exp((17.27 * temperature) / (237.7 + temperature))  # vapour pressure
    pv = e * 100  # vapour partial pressure in Pa
    return pv

# 대기 밀도, 절대 습도, 공기 분압 값을 데이터 프레임에 추가
train['air_density'] = air_density(train['pressure'], train['temperature'], train['humidity'])
test['air_density'] = air_density(test['pressure'], test['temperature'], test['humidity'])

train['absolute_humidity'] = calculate_absolute_humidity(train['temperature'], train['pressure'], train['humidity'])
test['absolute_humidity'] = calculate_absolute_humidity(test['temperature'], test['pressure'], test['humidity'])

train['air_pressure'] = calculate_air_pressure(train['pressure'], train['temperature'], train['humidity'])
test['air_pressure'] = calculate_air_pressure(test['pressure'], test['temperature'], test['humidity'])


# 독립변수와 종속변수 분리
train_x = train.drop(columns=['id', 'target'])
train_y = train['target']
test_x = test.drop(columns=['id'])

# 레이블 인코딩
le = LabelEncoder()
train_x['snowing'] = le.fit_transform(train_x['snowing'])

for label in np.unique(test_x['snowing']):
    if label not in le.classes_:
        le.classes_ = np.append(le.classes_, label)
test_x['snowing'] = le.transform(test_x['snowing'])

# 스케일링
scaler = MaxAbsScaler()
transformed_train_X = scaler.fit_transform(train_x)
transformed_test_X = scaler.transform(test_x)

# Hyperparameter Optimization with Cross-validation
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, 10),
        'max_depth': trial.suggest_int('max_depth',20, 50),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 2),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 4),
        'max_features': trial.suggest_categorical('max_features', [None]),
        'bootstrap': trial.suggest_categorical('bootstrap', [False])
    }

    model = ExtraTreesRegressor(**params, random_state=42)

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    mae_scores = []
    for train_idx, valid_idx in kf.split(transformed_train_X):
        X_train_fold, X_valid_fold = transformed_train_X[train_idx], transformed_train_X[valid_idx]
        y_train_fold, y_valid_fold = train_y.iloc[train_idx], train_y.iloc[valid_idx]

        model.fit(X_train_fold, y_train_fold)
        preds = model.predict(X_valid_fold)
        mae_scores.append(mean_absolute_error(y_valid_fold, preds))

    return np.mean(mae_scores)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=150,n_jobs=-1)  # 줄어든 n_trials로 변경

# Best Model
params = study.best_params
model = ExtraTreesRegressor(**params, random_state=42)
model.fit(transformed_train_X, train['target'])
preds = model.predict(transformed_test_X)

# Submission
submit = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python3/sample_submission.csv')
submit['target'] = preds
submit.to_csv('/content/drive/MyDrive/Colab Notebooks/python3/yangjinyeong.csv', index=False)
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.12.0)
# Requirement already satisfied: cmaes>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (0.10.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# [I 2023-09-02 11:52:03,548] A new study created in memory with name: no-name-079eb4f2-3f4d-48c7-9ce8-b728ec421038
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# [I 2023-09-02 11:52:44,732] Trial 7 finished with value: 1.911923065213528 and parameters: {'n_estimators': 120, 'max_depth': 48, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:53:20,385] Trial 0 finished with value: 2.010636665227877 and parameters: {'n_estimators': 380, 'max_depth': 26, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:53:26,390] Trial 5 finished with value: 2.0518491244015538 and parameters: {'n_estimators': 450, 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:53:36,400] Trial 4 finished with value: 1.9400258474398455 and parameters: {'n_estimators': 350, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:53:46,468] Trial 6 finished with value: 1.9526268241587306 and parameters: {'n_estimators': 430, 'max_depth': 42, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:53:48,569] Trial 1 finished with value: 1.9533604360719745 and parameters: {'n_estimators': 440, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:53:54,470] Trial 2 finished with value: 2.0535277205823745 and parameters: {'n_estimators': 610, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:53:59,692] Trial 3 finished with value: 2.051509603751402 and parameters: {'n_estimators': 630, 'max_depth': 44, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:54:04,078] Trial 10 finished with value: 1.9563418355183626 and parameters: {'n_estimators': 160, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:54:58,140] Trial 15 finished with value: 2.0111796196090728 and parameters: {'n_estimators': 290, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:55:10,819] Trial 9 finished with value: 2.010463155227069 and parameters: {'n_estimators': 550, 'max_depth': 28, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 7 with value: 1.911923065213528.
# [I 2023-09-02 11:55:23,047] Trial 12 finished with value: 1.90711188613473 and parameters: {'n_estimators': 290, 'max_depth': 38, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 1.90711188613473.
# [I 2023-09-02 11:55:39,759] Trial 11 finished with value: 2.059899501555798 and parameters: {'n_estimators': 700, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 1.90711188613473.
# [I 2023-09-02 11:56:08,376] Trial 13 finished with value: 2.051101069605067 and parameters: {'n_estimators': 770, 'max_depth': 46, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 1.90711188613473.
# [I 2023-09-02 11:56:20,130] Trial 14 finished with value: 2.0511478784371677 and parameters: {'n_estimators': 790, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 1.90711188613473.
# [I 2023-09-02 11:56:35,606] Trial 8 finished with value: 1.9528884106235374 and parameters: {'n_estimators': 980, 'max_depth': 48, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 1.90711188613473.
# [I 2023-09-02 11:56:53,291] Trial 22 finished with value: 1.91257749517798 and parameters: {'n_estimators': 100, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 1.90711188613473.
# [I 2023-09-02 11:57:12,643] Trial 23 finished with value: 1.911575825096343 and parameters: {'n_estimators': 110, 'max_depth': 38, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 1.90711188613473.
# [I 2023-09-02 11:57:41,848] Trial 16 finished with value: 1.9530189309969217 and parameters: {'n_estimators': 920, 'max_depth': 39, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 1.90711188613473.
# [I 2023-09-02 11:58:18,278] Trial 24 finished with value: 1.9067540942512582 and parameters: {'n_estimators': 250, 'max_depth': 37, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 24 with value: 1.9067540942512582.
# [I 2023-09-02 11:58:30,691] Trial 25 finished with value: 1.9077001454287608 and parameters: {'n_estimators': 230, 'max_depth': 38, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 24 with value: 1.9067540942512582.
# [I 2023-09-02 11:59:06,231] Trial 26 finished with value: 1.9069545510942767 and parameters: {'n_estimators': 250, 'max_depth': 38, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 24 with value: 1.9067540942512582.
# [I 2023-09-02 11:59:34,152] Trial 27 finished with value: 1.907562135129692 and parameters: {'n_estimators': 230, 'max_depth': 37, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 24 with value: 1.9067540942512582.
# [I 2023-09-02 11:59:49,791] Trial 28 finished with value: 1.9069395140122467 and parameters: {'n_estimators': 240, 'max_depth': 37, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 24 with value: 1.9067540942512582.
# [I 2023-09-02 12:00:00,248] Trial 17 finished with value: 1.9048376927908328 and parameters: {'n_estimators': 900, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 17 with value: 1.9048376927908328.
# [I 2023-09-02 12:00:23,978] Trial 29 finished with value: 1.9085897483195169 and parameters: {'n_estimators': 240, 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 17 with value: 1.9048376927908328.
# [I 2023-09-02 12:00:31,226] Trial 19 finished with value: 1.9045892288675408 and parameters: {'n_estimators': 930, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 19 with value: 1.9045892288675408.
# [I 2023-09-02 12:00:41,798] Trial 18 finished with value: 1.9045520645975593 and parameters: {'n_estimators': 990, 'max_depth': 49, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 18 with value: 1.9045520645975593.
# [I 2023-09-02 12:00:51,233] Trial 30 finished with value: 1.9085897483195169 and parameters: {'n_estimators': 240, 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 18 with value: 1.9045520645975593.
# [I 2023-09-02 12:00:54,593] Trial 20 finished with value: 1.904490830179995 and parameters: {'n_estimators': 950, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:00:55,319] Trial 31 finished with value: 1.9100936408673763 and parameters: {'n_estimators': 200, 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:01:39,766] Trial 21 finished with value: 1.9045707015281799 and parameters: {'n_estimators': 1000, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:03:22,283] Trial 32 finished with value: 1.9526447481800848 and parameters: {'n_estimators': 870, 'max_depth': 29, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:03:45,298] Trial 33 finished with value: 1.953310258668902 and parameters: {'n_estimators': 860, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:03:54,685] Trial 34 finished with value: 1.952864245892524 and parameters: {'n_estimators': 870, 'max_depth': 49, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:04:08,057] Trial 35 finished with value: 1.952961794511004 and parameters: {'n_estimators': 880, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:04:17,732] Trial 36 finished with value: 1.952961794511004 and parameters: {'n_estimators': 880, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:04:20,879] Trial 38 finished with value: 1.952961794511004 and parameters: {'n_estimators': 880, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:04:45,487] Trial 37 finished with value: 1.9529023000532675 and parameters: {'n_estimators': 990, 'max_depth': 46, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:05:29,995] Trial 39 finished with value: 1.9528944543452855 and parameters: {'n_estimators': 990, 'max_depth': 47, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:07:10,415] Trial 40 finished with value: 1.9528944543452855 and parameters: {'n_estimators': 990, 'max_depth': 47, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:07:33,937] Trial 41 finished with value: 1.9529023000532675 and parameters: {'n_estimators': 990, 'max_depth': 46, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:09:11,322] Trial 42 finished with value: 1.9046148788192023 and parameters: {'n_estimators': 990, 'max_depth': 45, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:09:31,709] Trial 43 finished with value: 1.9046509566832661 and parameters: {'n_estimators': 1000, 'max_depth': 45, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:09:43,822] Trial 44 finished with value: 1.9045664370675948 and parameters: {'n_estimators': 1000, 'max_depth': 46, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:09:45,324] Trial 45 finished with value: 1.9045664370675948 and parameters: {'n_estimators': 1000, 'max_depth': 46, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:09:55,533] Trial 46 finished with value: 1.9045313228052028 and parameters: {'n_estimators': 950, 'max_depth': 47, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:10:37,619] Trial 47 finished with value: 1.9046328502815075 and parameters: {'n_estimators': 940, 'max_depth': 45, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:11:58,454] Trial 49 finished with value: 1.9047163361824517 and parameters: {'n_estimators': 800, 'max_depth': 45, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:12:24,719] Trial 48 finished with value: 1.904584119646723 and parameters: {'n_estimators': 950, 'max_depth': 45, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:14:08,443] Trial 52 finished with value: 1.9045054757323618 and parameters: {'n_estimators': 810, 'max_depth': 41, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 1.904490830179995.
# [I 2023-09-02 12:14:14,794] Trial 53 finished with value: 1.904328920299281 and parameters: {'n_estimators': 820, 'max_depth': 41, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 53 with value: 1.904328920299281.
# [I 2023-09-02 12:14:21,303] Trial 54 finished with value: 1.904719689493329 and parameters: {'n_estimators': 810, 'max_depth': 42, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 53 with value: 1.904328920299281.
# [I 2023-09-02 12:14:23,178] Trial 50 finished with value: 1.9043219472573187 and parameters: {'n_estimators': 940, 'max_depth': 41, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 50 with value: 1.9043219472573187.
# [I 2023-09-02 12:14:42,262] Trial 56 finished with value: 2.0095063507398216 and parameters: {'n_estimators': 820, 'max_depth': 42, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 50 with value: 1.9043219472573187.
# [I 2023-09-02 12:14:42,600] Trial 51 finished with value: 1.9043219472573187 and parameters: {'n_estimators': 940, 'max_depth': 41, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 50 with value: 1.9043219472573187.
# [I 2023-09-02 12:14:52,275] Trial 55 finished with value: 1.9047146439079312 and parameters: {'n_estimators': 780, 'max_depth': 42, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 50 with value: 1.9043219472573187.
# [I 2023-09-02 12:15:09,038] Trial 57 finished with value: 2.0095181826479456 and parameters: {'n_estimators': 830, 'max_depth': 41, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 50 with value: 1.9043219472573187.
# [I 2023-09-02 12:16:42,281] Trial 61 finished with value: 2.0096927566140566 and parameters: {'n_estimators': 710, 'max_depth': 41, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 50 with value: 1.9043219472573187.
# [I 2023-09-02 12:18:08,253] Trial 59 finished with value: 1.9047901367086897 and parameters: {'n_estimators': 720, 'max_depth': 41, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 50 with value: 1.9043219472573187.
# [I 2023-09-02 12:18:08,889] Trial 60 finished with value: 1.9048651898887048 and parameters: {'n_estimators': 700, 'max_depth': 41, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 50 with value: 1.9043219472573187.
# [I 2023-09-02 12:18:34,862] Trial 63 finished with value: 1.9042706908864102 and parameters: {'n_estimators': 710, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 63 with value: 1.9042706908864102.
# [I 2023-09-02 12:18:36,230] Trial 58 finished with value: 1.9039878442320586 and parameters: {'n_estimators': 820, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:18:41,601] Trial 62 finished with value: 1.9043105410014465 and parameters: {'n_estimators': 730, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:18:52,272] Trial 64 finished with value: 1.9043105410014465 and parameters: {'n_estimators': 730, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:18:53,708] Trial 65 finished with value: 1.904541852952018 and parameters: {'n_estimators': 680, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:20:45,224] Trial 66 finished with value: 1.9044672143481107 and parameters: {'n_estimators': 720, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:21:23,351] Trial 67 finished with value: 1.9057055684790147 and parameters: {'n_estimators': 560, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:22:06,933] Trial 71 finished with value: 1.905591108985448 and parameters: {'n_estimators': 580, 'max_depth': 39, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:22:18,853] Trial 70 finished with value: 1.9049834844909994 and parameters: {'n_estimators': 630, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:22:34,262] Trial 72 finished with value: 1.905250032521566 and parameters: {'n_estimators': 630, 'max_depth': 39, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:22:38,343] Trial 73 finished with value: 1.9051588864493945 and parameters: {'n_estimators': 640, 'max_depth': 39, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:23:01,710] Trial 69 finished with value: 1.904337765348546 and parameters: {'n_estimators': 750, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:23:34,163] Trial 68 finished with value: 1.904239443869526 and parameters: {'n_estimators': 920, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:24:29,857] Trial 74 finished with value: 1.9052813638210242 and parameters: {'n_estimators': 620, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:25:10,777] Trial 75 finished with value: 1.9050373001976006 and parameters: {'n_estimators': 640, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:25:16,447] Trial 77 finished with value: 1.906209906837385 and parameters: {'n_estimators': 500, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:26:34,074] Trial 76 finished with value: 1.9041265942696373 and parameters: {'n_estimators': 750, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:26:46,646] Trial 79 finished with value: 1.9112099962063733 and parameters: {'n_estimators': 750, 'max_depth': 24, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:27:01,072] Trial 78 finished with value: 1.9045981340621274 and parameters: {'n_estimators': 750, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:27:18,265] Trial 82 finished with value: 1.9066134223903461 and parameters: {'n_estimators': 470, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:27:34,617] Trial 80 finished with value: 1.9044735668810968 and parameters: {'n_estimators': 760, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:28:00,919] Trial 81 finished with value: 1.9045981340621274 and parameters: {'n_estimators': 750, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:29:10,972] Trial 87 finished with value: 2.051564433248177 and parameters: {'n_estimators': 670, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:29:42,335] Trial 86 finished with value: 2.0514140694072305 and parameters: {'n_estimators': 910, 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:29:44,668] Trial 84 finished with value: 1.9041265942696373 and parameters: {'n_estimators': 750, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 58 with value: 1.9039878442320586.
# [I 2023-09-02 12:30:34,110] Trial 83 finished with value: 1.9037348282651803 and parameters: {'n_estimators': 910, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 83 with value: 1.9037348282651803.
# [I 2023-09-02 12:30:59,547] Trial 85 finished with value: 1.9041265942696373 and parameters: {'n_estimators': 750, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 83 with value: 1.9037348282651803.
# [I 2023-09-02 12:32:37,603] Trial 88 finished with value: 1.9037348282651803 and parameters: {'n_estimators': 910, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 83 with value: 1.9037348282651803.
# [I 2023-09-02 12:32:53,477] Trial 89 finished with value: 1.9044476806806365 and parameters: {'n_estimators': 910, 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 83 with value: 1.9037348282651803.
# [I 2023-09-02 12:33:21,412] Trial 90 finished with value: 1.9037667373807292 and parameters: {'n_estimators': 910, 'max_depth': 37, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 83 with value: 1.9037348282651803.
# [I 2023-09-02 12:34:03,419] Trial 91 finished with value: 1.9035591710409967 and parameters: {'n_estimators': 830, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 91 with value: 1.9035591710409967.
# [I 2023-09-02 12:34:32,912] Trial 92 finished with value: 1.9035591710409967 and parameters: {'n_estimators': 830, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 91 with value: 1.9035591710409967.
# [I 2023-09-02 12:34:44,321] Trial 93 finished with value: 1.9035505253126719 and parameters: {'n_estimators': 850, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:35:34,677] Trial 94 finished with value: 1.9035505253126719 and parameters: {'n_estimators': 850, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:36:00,088] Trial 95 finished with value: 1.903992152819939 and parameters: {'n_estimators': 850, 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:37:39,010] Trial 96 finished with value: 1.9040397895103205 and parameters: {'n_estimators': 840, 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:37:57,190] Trial 97 finished with value: 1.9035505253126719 and parameters: {'n_estimators': 850, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:37:59,851] Trial 98 finished with value: 1.9038887588664728 and parameters: {'n_estimators': 780, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:39:04,122] Trial 99 finished with value: 1.9035505253126719 and parameters: {'n_estimators': 850, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:39:31,775] Trial 100 finished with value: 1.9035505253126719 and parameters: {'n_estimators': 850, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:39:38,393] Trial 101 finished with value: 1.9035591710409967 and parameters: {'n_estimators': 830, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:40:36,002] Trial 102 finished with value: 1.9037274257510035 and parameters: {'n_estimators': 860, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:40:54,400] Trial 103 finished with value: 1.9040397895103205 and parameters: {'n_estimators': 840, 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:42:37,682] Trial 104 finished with value: 1.903992152819939 and parameters: {'n_estimators': 850, 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
# [I 2023-09-02 12:42:55,898] Trial 105 finished with value: 1.904166338849955 and parameters: {'n_estimators': 850, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 93 with value: 1.9035505253126719.
